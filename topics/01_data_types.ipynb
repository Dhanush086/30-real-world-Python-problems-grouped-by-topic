# %% [markdown]
# # 🧠 Topic 01: Data Types & Variables
#
# In this notebook, we explore how to use different data types in Python to store and process real-world information.
#
# We cover:
# - Strings (`str`) for names, labels, and text
# - Integers (`int`) for whole numbers like age or quantity
# - Floats (`float`) for decimal values like temperature or price
# - Booleans (`bool`) for yes/no or true/false decisions
#
# These data types are the building blocks of all Python programs. The examples below simulate real-world tasks using variables and `type()` checking.

# %% [markdown]
# # 🐍 Introduction to Python – Real-World Scenario

# %% [markdown]
# 🏥 Medication Dosage Tracker
#
# A junior nurse at Apollo Hospital needs help calculating insulin dosage for a diabetic patient. The nurse lacks programming skills and needs assistance with:
#
# - Tracking shots (int)
# - Dosage per shot (float)
# - Patient flags (bool)
# - Displaying info (str)
#
# You will write a Python program that calculates total dosage and checks data types.

# %% [markdown]
# ![download (1).jpg](data:image/jpeg;base64,...)

# %%
# --- Patient Info & Medical Data ---

# String (str): Text data
patient_name = "Deepak Sharma"
condition_status = "Critical"

# Integer (int): Whole numbers
age = 67
daily_shots = 3

# Float: Decimal values
insulin_per_shot = 12.5

# Boolean (bool): True/False flags
has_insurance = True

# %%
# --- Insulin Dosage Calculation ---

# Calculate total insulin dosage for the day
total_daily_dosage = daily_shots * insulin_per_shot

# %%
# --- Display Patient Report ---
print(f"Total Daily Dosage: {total_daily_dosage} units")
# Out:
# Total Daily Dosage: 37.5 units

# %% [markdown]
# 🥗 Nutritional Tracker for a Patient
#
# A dietician at Fortis Hospital is managing the nutritional intake of a patient recovering from surgery. The patient requires a precise calculation of their daily protein, carb, and fat intake. You’ve been asked to help the dietician create a Python program that tracks:
#
# Food item names (str)
#
# Quantity in grams (int)
#
# Calories per gram (float)
#
# Flags for whether the food is vegetarian (bool)

# %% [markdown]
# ![nutritionist-doctor-writing-diet-plan-table_192941-323.avif](data:image/avif;base64,...)

# %%
# --- Patient Nutrition Log ---
food_item = "Boiled Eggs"
quantity_g = 120
calories_per_g = 1.43
is_vegetarian = False

# %%
# --- Total Calorie Calculation ---

total_calories = quantity_g * calories_per_g

# %%
print(f"Total Calories: {total_calories}")
# Out:
# Total Calories: 171.6

# %% [markdown]
# # Data types in python

# %% [markdown]
# 📋 Patient Health Report Generator
#
# You are a junior data technician in a hospital. Your task is to build a simple health report generator using Python. This generator collects basic patient data like name, ID, temperature, and other health indicators.
#
# Different data types are used for different kinds of information:
#
# 📝 Strings for name and blood type
#
# 🔢 Integers for age and ID
#
# 🔬 Floats for temperature and BMI
#
# ✅ Booleans for smoking and insurance status
#
# At the end, your code should print a formatted health report and also verify each data type using the type() function.
#
# This helps hospital staff check if all patient info is correctly typed before storing it in the system.

# %% [markdown]
# ![patient health report.jpg](data:image/jpeg;base64,...)

# %%
# --- Patient Vitals: Defining Variables ---

# string
patient_name = "Maria Santos"
blood_type = "O+"

# int
age = 58
heart_rate = 76

# float
temperature = 36.7
bmi = 23.4

# bool
is_smoker = False
has_insurance = True

# %% [markdown]
# Display report

# %%
# --- Displaying the Report ---

print("--- Patient Health Report ---")
print(f"Name: {patient_name}")
print(f"Age: {age}")
print(f"Blood Type: {blood_type}")
print(f"Temperature: {temperature}°C")
print(f"BMI: {bmi}")
print(f"Smoker: {is_smoker}")
print(f"Insurance: {has_insurance}")
# Out:
# --- Patient Health Report ---
# Name: Maria Santos
# Age: 58
# Blood Type: O+
# Temperature: 36.7°C
# BMI: 23.4
# Smoker: False
# Insurance: True

# %% [markdown]
# code data type

# %%
# --- Type Checking ---

print("\n--- Verifying Data Types ---")
print(f"Type of patient_name: {type(patient_name)}")
print(f"Type of age: {type(age)}")
print(f"Type of temperature: {type(temperature)}")
print(f"Type of is_smoker: {type(is_smoker)}")
# Out:
# --- Verifying Data Types ---
# Type of patient_name: <class 'str'>
# Type of age: <class 'int'>
# Type of temperature: <class 'float'>
# Type of is_smoker: <class 'bool'>

# %% [markdown]
# 💊 Pharmacy Billing System

# %% [markdown]
# A pharmacist wants to bill a customer for their medicine purchase. The details include:
#
# Customer name (string)
#
# Medicine name (string)
#
# Quantity bought (int)
#
# Price per tablet (float)
#
# Is prescription required (bool)
#
# Write a Python program using these data types and display the bill.

# %% [markdown]
# ![medical billing.jpg](data:image/jpeg;base64,...)

# %%
# --- Pharmacy Billing System ---

# Data (using basic data types)
customer_name = "Rohan Gupta"           # string
medicine_name = "Paracetamol 500mg"     # string
quantity = 20                           # int
price_per_unit = 2.50                   # float
prescription_required = False           # bool

# Display Bill
print("--- Pharmacy Bill ---")
print(f"Customer: {customer_name}")
print(f"Medicine: {medicine_name}")
print(f"Quantity: {quantity}")
print(f"Price per unit: ₹{price_per_unit}")
print(f"Prescription needed: {prescription_required}")

# Data Type Check
print("\n--- Data Types ---")
print(type(customer_name))
print(type(medicine_name))
print(type(quantity))
print(type(price_per_unit))
print(type(prescription_required))
# Out:
# --- Pharmacy Bill ---
# Customer: Rohan Gupta
# Medicine: Paracetamol 500mg
# Quantity: 20
# Price per unit: ₹2.5
# Prescription needed: False
#
# --- Data Types ---
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
